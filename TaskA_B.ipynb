# %% [markdown]
# # Task A: MongoDB Data Model
#
# ## There will be two collections based on our model design:Climate and Hotspot
# ## Here is a sample data:
# climate = {<br/>
#             'station':948700,<br/>
#            'date':ISODate("2016-12-31T00:00:00Z"),<br/>
#            'air_temperature_celcius':19,<br/>
#            'relative_humidity':56.8,<br/>
#            'windspeed_knots':7.9,<br/>
#            'max_wind_speed':11.1,<br/>
#            'precipitation':"0.00I"}<br/>
#            }<br/>
#
# hotspot = {
# <br/>'latitude':-37.966,<br/>
#            'longitude':145.051,<br/>
#            'datetime':ISODate("2017-12-27T04:16:51"),<br/>
#            'confidence':78,<br/>
#            'date':ISODate("2017-12-27T00:00:00"),<br/>
#            'surface_temperature_celcius':68}<br/>
#           }<br/>
# ## Justification:
# Based on our understanding of data modelling in Mongo, embedding is usually used when the application need to retrieve the complete patron information with a single query while referencing is used when one collection has a large number of records.<br/>
#
# After looking through the given data of climate and hotspot, we found that the highest number of hotspot records in a single day is around 360 which isn't that large in general, also since it's historic data, we assume the hotspot data is bounded. Due to these reasons, we think using referencing model in this situation might not be appropriate. <br/>
#
# Besides, considering the query we are offered in task B, join these two collections using "lookup" based on the common attribute 'date' is apparently a easier way to perform the query than under embedding model, which makes us believe it's unnecessary to apply embedding in this case.<br/>

# %% [markdown]
# # Task B: Read data into Mongo & Query

# %%
## Task B_1

# Import csv module and pymongo module
import pandas as pd
import pymongo
from pymongo import MongoClient
import datetime


# Set up file path of csv file
filename_hotspot = 'hotspot_historic.csv' 
filename_climate = 'climate_historic.csv'


# Set up connection with MongoDB
client = MongoClient()

# Set up database
db = client.fit5148_assignment_db

# Drop both collection in before inserting
drop_hotspot = db.hotspot.drop()
drop_climate = db.climate.drop()

# Set up collection
collection_hotspot = db.hotspot
collection_climate = db.climate

# Read csv file as dataframe
hotspot_file = pd.read_csv(filename_hotspot)
climate_file = pd.read_csv(filename_climate)

# Change Hotspot datatype
hotspot_file['confidence'] = hotspot_file['confidence'].astype('int64')
hotspot_file['latitude'] = hotspot_file['latitude'].astype('float')
hotspot_file['longitude'] = hotspot_file['longitude'].astype('float')
hotspot_file['datetime'] = pd.to_datetime(hotspot_file['datetime'])
hotspot_file['date'] = pd.to_datetime(hotspot_file['date'])
hotspot_file['surface_temperature_celcius'] = hotspot_file['surface_temperature_celcius'].astype('int64')

# Load Hotspot data into mongo
insert_hotspot = collection_hotspot.insert_many(hotspot_file.to_dict('records'))

# Change Hotspot datatype
climate_file['air_temperature_celcius'] = climate_file['air_temperature_celcius'].astype('int64')
climate_file['station'] = climate_file['station'].astype('int64')
climate_file['relative_humidity'] = climate_file['relative_humidity'].astype('float')
climate_file['max_wind_speed'] = climate_file['max_wind_speed'].astype('float')
climate_file['windspeed_knots'] = climate_file['windspeed_knots'].astype('float')
climate_file['date'] = pd.to_datetime(climate_file['date'])


# Load Climate data into mongo
insert_climate = collection_climate.insert_many(climate_file.to_dict('records'))

# %%
# Q_a
from pprint import pprint
date_search = datetime.datetime(2017,12,10)
result = collection_climate.find({'date' : date_search})
for doc in result:
    pprint(doc)
# Out:
# {'_id': ObjectId('5ce7d6909343690e427b76d3'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2017, 12, 10, 0, 0),
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 44.5,
#  'station': 948702,
#  'windspeed_knots': 10.2}

# %%
# Q_b
results = collection_hotspot.find({'surface_temperature_celcius':{"$gte":65, '$lte':100}
                                  }, {'_id':0, 'latitude':1, 'longitude':1, 'confidence':1, 'surface_temperature_celcius':1})
for result in results:
    pprint(result)
# Out:
# {'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.05100000000002,
#  'surface_temperature_celcius': 68}
# {'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -38.056999999999995,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.641999999999996,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.30200000000002,
#  'surface_temperature_celcius': 83}
# {'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.30700000000002,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.35399999999998,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -37.861999999999995,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -37.330999999999996,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -37.294000000000004,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -38.126999999999995,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.461999999999996,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.08100000000002,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.400999999999996,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
# {'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
# {'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
# {'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.663000000000004,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
# {'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.803000000000004,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.27200000000002,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'confidence': 93,
#  'latitude': -36.388000000000005,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
# {'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.53799999999998,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
# {'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.97799999999998,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'confidence': 93,
#  'latitude': -36.663000000000004,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
# {'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
# {'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
# {'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
# {'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
# {'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
# {'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
# {'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
# {'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
# {'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
# {'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
# {'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
# {'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
# {'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
# {'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -36.7287,
#  'longitude': 142.6017,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
# {'confidence': 98,
#  'latitude': -35.2381,
#  'longitude': 142.994,
#  'surface_temperature_celcius': 83}
# {'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
# {'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.224000000000004,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
# {'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
# {'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
# {'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'confidence': 83,
#  'latitude': -37.803000000000004,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.08100000000002,
#  'surface_temperature_celcius': 81}
# {'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
# {'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.91299999999998,
#  'surface_temperature_celcius': 83}
# {'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
# {'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
# {'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.72799999999998,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
# {'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.89700000000002,
#  'surface_temperature_celcius': 80}
# {'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
# {'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
# {'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.02700000000002,
#  'surface_temperature_celcius': 99}
# {'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}

# %%
# Q_c
date_search_15 = datetime.datetime(2017,12,15)
date_search_16 = datetime.datetime(2017,12,16)
result = collection_climate.aggregate([
        {
            "$match": { "$or" :[ {"date":date_search_15}, {"date":date_search_16} ]}   
        },
        {
            "$lookup":
            {
                "from": "hotspot",
                "localField": "date",
                "foreignField": "date",
                "as": "fire_records"
            }       
        },
        {
             "$unwind":"$fire_records"
        },
        {
             "$project": {
                 "_id":0,
                 "date":1,
                 "fire_records.surface_temperature_celcius":1,
                 "max_wind_speed":1,
                 "relative_humidity":1,
                 "air_temperature_celcius":1
             }
         }
        ])
for item in result:
    pprint(item)
# Out:
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 15, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 42},
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 15, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 36},
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 15, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 38},
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 15, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 40},
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 33},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 54},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 75},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 66},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 56},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 60},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 48},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 64},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2017, 12, 16, 0, 0),
#  'fire_records': {'surface_temperature_celcius': 57},
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
# Q_d
result = collection_hotspot.aggregate([
        {
            "$match": {'confidence':{"$gte":80, '$lte':100}
                                  }   
        },
        {
            "$lookup":
            {
                "from": "climate",
                "localField": "date",
                "foreignField": "date",
                "as": "climate_records"
            }       
        },
         {
              "$project": {
                  "_id":0,
                  "confidence":1,
                  "datetime":1,
                  "surface_temperature_celcius":1,
                  "climate_records.air_temperature_celcius":1
              }
          }
        ])
for item in result:
    pprint(item)
# Out:
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 12, 27, 0, 2, 15),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 12, 27, 0, 2, 14),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 12, 25, 4, 29, 8),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 12, 16, 15, 38, 39),
#  'surface_temperature_celcius': 43}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 12, 16, 4, 35, 13),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 12, 16, 4, 34, 57),
#  'surface_temperature_celcius': 66}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 12, 16, 0, 21, 12),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 12, 16, 0, 21, 11),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 12, 16, 0, 20, 53),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 12, 15, 13, 17, 17),
#  'surface_temperature_celcius': 42}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 12, 14, 4, 47, 25),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 12, 13, 4, 4, 19),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 71}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 12, 8, 13, 11, 43),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 15, 38, 36),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 49}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 38}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 42}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 30, 12, 22, 14),
#  'surface_temperature_celcius': 71}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 11, 30, 4, 35),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 83}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 86}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 29, 13, 17, 24),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 87}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 84}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 11, 22, 3, 46),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 11, 22, 3, 46),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 11, 21, 0, 27, 21),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 28}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 11, 14, 4, 35, 4),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 11, 13, 3, 52, 15),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 11, 13, 3, 52, 14),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 11, 12, 0, 33, 15),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 37}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 11, 11, 4, 4, 25),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 93}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 11, 5, 4, 41, 34),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 10, 28, 3, 52, 17),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 22}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 10, 27, 4, 47, 31),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 10, 21, 1, 9, 55),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 10, 21, 1, 9, 54),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 46}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 50}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 26}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 22}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 10, 17, 13, 36, 12),
#  'surface_temperature_celcius': 43}
# {'climate_records': [{'air_temperature_celcius': 22}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 10, 17, 4, 10, 45),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 22}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 10, 17, 4, 10, 32),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 87}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 85}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 10, 10, 4, 4, 19),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 10, 7, 12, 59, 33),
#  'surface_temperature_celcius': 42}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 10, 4, 4, 41, 2),
#  'surface_temperature_celcius': 46}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 10, 4, 4, 41),
#  'surface_temperature_celcius': 46}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 10, 4, 4, 41),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 10, 4, 4, 41),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 10, 3, 13, 23, 43),
#  'surface_temperature_celcius': 42}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 49}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 90}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 10, 2, 4, 53, 10),
#  'surface_temperature_celcius': 50}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 10, 2, 4, 53, 9),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 10, 1, 15, 13, 56),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 9, 29, 4, 22, 31),
#  'surface_temperature_celcius': 49}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 41}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 43}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 13, 30, 10),
#  'surface_temperature_celcius': 47}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 38}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 9, 24, 13, 30, 7),
#  'surface_temperature_celcius': 50}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 24, 4, 4, 19),
#  'surface_temperature_celcius': 88}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 9, 24, 4, 4, 18),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 9, 24, 4, 4, 4),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 9, 23, 23, 50, 44),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 50}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 84}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 79}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 9, 23, 4, 59, 13),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 50}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 112}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 9, 20, 4, 28, 45),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 9, 10, 4, 0),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 9, 10, 3, 53),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 9, 10, 3, 50, 30),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 9, 10, 3, 50, 10),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 8, 13, 5, 8),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 8, 13, 5, 5, 10),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 8, 13, 5, 2, 30),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 5}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 8, 2, 3, 45, 40),
#  'surface_temperature_celcius': 87}
# {'climate_records': [{'air_temperature_celcius': 7}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 8, 1, 0, 20, 30),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 7}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 7, 31, 13, 21),
#  'surface_temperature_celcius': 51}
# {'climate_records': [{'air_temperature_celcius': 7}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 7, 31, 13, 21),
#  'surface_temperature_celcius': 43}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 7, 6, 4, 8),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 7, 6, 4, 2),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#  'surface_temperature_celcius': 88}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#  'surface_temperature_celcius': 89}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 6, 14, 4, 43),
#  'surface_temperature_celcius': 85}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 6, 9, 4, 23, 20),
#  'surface_temperature_celcius': 52}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 6, 9, 4, 23, 16),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 35, 50),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 33, 50),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 8}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 6, 4, 4, 8, 20),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 6, 4, 4, 8, 10),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 11}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 6, 1, 5, 9, 20),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 13}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 26, 4, 8, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 23, 0, 58),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 23, 0, 54, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 43, 30),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 34, 10),
#  'surface_temperature_celcius': 101}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 82}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 93}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 22, 0, 15),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 22, 0, 13),
#  'surface_temperature_celcius': 90}
# {'climate_records': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 5, 22, 0, 13),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 33),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 33),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 101}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 31, 20),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 31, 10),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 30),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 28),
#  'surface_temperature_celcius': 94}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 28),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 28),
#  'surface_temperature_celcius': 87}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 27, 50),
#  'surface_temperature_celcius': 66}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 111}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 66}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 110}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 15, 0, 12, 10),
#  'surface_temperature_celcius': 90}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 45, 40),
#  'surface_temperature_celcius': 102}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 43, 30),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 41, 50),
#  'surface_temperature_celcius': 98}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 40, 20),
#  'surface_temperature_celcius': 120}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 40, 10),
#  'surface_temperature_celcius': 90}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 39, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 39, 30),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 39),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 50),
#  'surface_temperature_celcius': 93}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 113}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 95}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 12, 3, 57, 40),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 5, 12, 3, 56, 10),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 12, 3, 56, 10),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 57, 20),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 57, 20),
#  'surface_temperature_celcius': 79}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 54),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 51),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 86}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 69}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 81}
# {'climate_records': [{'air_temperature_celcius': 9}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 16, 30),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 16, 10),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 14, 20),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 14, 10),
#  'surface_temperature_celcius': 103}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 12, 50),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 12, 50),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 11, 30),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 83}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 82}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 84}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 78}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 71}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 89}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 113}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
# ...
#  'surface_temperature_celcius': 72}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 4, 3, 1, 7, 20),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 3, 31, 5, 7, 10),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 31, 5, 1, 20),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 3, 31, 4, 58, 30),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 3, 31, 4, 58),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 3, 31, 4, 57, 10),
#  'surface_temperature_celcius': 61}
# {'climate_records': [{'air_temperature_celcius': 14}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 31, 0, 36, 30),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 38),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 33, 40),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 33, 30),
#  'surface_temperature_celcius': 71}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 33, 30),
#  'surface_temperature_celcius': 76}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 32, 20),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 50),
#  'surface_temperature_celcius': 56}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 20),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 74}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 82}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 27, 40),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 27, 20),
#  'surface_temperature_celcius': 107}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 27, 10),
#  'surface_temperature_celcius': 108}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 27),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 27),
#  'surface_temperature_celcius': 86}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 90}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 63}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 43, 20),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 40, 50),
#  'surface_temperature_celcius': 53}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 50),
#  'surface_temperature_celcius': 54}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 89}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 59, 50),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 111}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 77}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 25, 3, 56, 40),
#  'surface_temperature_celcius': 99}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 39, 50),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 39, 20),
#  'surface_temperature_celcius': 79}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 36),
#  'surface_temperature_celcius': 66}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 33),
#  'surface_temperature_celcius': 83}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 91}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 113}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 70}
# {'climate_records': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 106}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50),
#  'surface_temperature_celcius': 121}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 18, 3, 50, 40),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 3, 17, 4, 48, 20),
#  'surface_temperature_celcius': 74}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 3, 17, 4, 45, 10),
#  'surface_temperature_celcius': 59}
# {'climate_records': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 3, 17, 4, 45),
#  'surface_temperature_celcius': 60}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 24, 40),
#  'surface_temperature_celcius': 67}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 22, 20),
#  'surface_temperature_celcius': 72}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 20, 50),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 16, 30),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 16, 20),
#  'surface_temperature_celcius': 65}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 14, 40),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 79}
# {'climate_records': [{'air_temperature_celcius': 25}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 75}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 3, 12, 4, 33, 50),
#  'surface_temperature_celcius': 105}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2017, 3, 12, 4, 29, 50),
#  'surface_temperature_celcius': 71}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 12, 4, 28, 20),
#  'surface_temperature_celcius': 99}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2017, 3, 12, 4, 28),
#  'surface_temperature_celcius': 68}
# {'climate_records': [{'air_temperature_celcius': 21}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 12, 4, 27, 20),
#  'surface_temperature_celcius': 98}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 10, 4, 48, 40),
#  'surface_temperature_celcius': 105}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2017, 3, 10, 4, 46, 20),
#  'surface_temperature_celcius': 109}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2017, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 73}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2017, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 80}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2017, 3, 10, 4, 43, 50),
#  'surface_temperature_celcius': 55}
# {'climate_records': [{'air_temperature_celcius': 23}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2017, 3, 9, 13, 23, 40),
#  'surface_temperature_celcius': 41}
# {'climate_records': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2017, 3, 7, 4, 16, 10),
#  'surface_temperature_celcius': 64}
# {'climate_records': [{'air_temperature_celcius': 20}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2017, 3, 6, 5, 6, 30),
#  'surface_temperature_celcius': 62}
# {'climate_records': [{'air_temperature_celcius': 20}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2017, 3, 6, 5, 6, 20),
#  'surface_temperature_celcius': 59}

# %%
# Q_e
results = collection_hotspot.find().sort([('surface_temperature_celcius',-1)]).limit(10)
for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('5ce7d6909343690e427b6fee'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 18, 4, 52),
#  'latitude': -38.1665,
#  'longitude': 143.062,
#  'surface_temperature_celcius': 124}
# {'_id': ObjectId('5ce7d6909343690e427b7498'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50),
#  'latitude': -36.343,
#  'longitude': 142.1986,
#  'surface_temperature_celcius': 123}
# {'_id': ObjectId('5ce7d6909343690e427b6f60'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 1, 5, 0, 0),
#  'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20),
#  'latitude': -36.9318,
#  'longitude': 143.0907,
#  'surface_temperature_celcius': 122}
# {'_id': ObjectId('5ce7d6909343690e427b7587'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 3, 18, 0, 0),
#  'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50),
#  'latitude': -37.016999999999996,
#  'longitude': 148.1297,
#  'surface_temperature_celcius': 121}
# {'_id': ObjectId('5ce7d6909343690e427b6d72'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2017, 5, 13, 4, 40, 20),
#  'latitude': -34.9938,
#  'longitude': 141.876,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce7d6909343690e427b7087'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50),
#  'latitude': -37.8326,
#  'longitude': 143.4999,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce7d6909343690e427b720a'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 13, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10),
#  'latitude': -37.0745,
#  'longitude': 141.0692,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce7d6909343690e427b745f'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 4, 4, 40),
#  'latitude': -36.1057,
#  'longitude': 141.7608,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce7d6909343690e427b749f'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40),
#  'latitude': -36.3521,
#  'longitude': 142.2008,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce7d6909343690e427b6eb6'),
#  'confidence': 100,
#  'date': datetime.datetime(2017, 4, 5, 0, 0),
#  'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50),
#  'latitude': -36.4057,
#  'longitude': 140.9806,
#  'surface_temperature_celcius': 119}

# %%
# Q_f
result = collection_hotspot.aggregate([
        {
             "$group": {
                 "_id":"$date", "total_numer_of_fire":{"$sum":1}
             }  
        }
        ])
for item in result:
    pprint(item)
# Out:
# {'_id': datetime.datetime(2017, 6, 3, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 8, 3, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 9, 3, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 3, 13, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 3, 15, 0, 0), 'total_numer_of_fire': 7}
# {'_id': datetime.datetime(2017, 3, 17, 0, 0), 'total_numer_of_fire': 6}
# {'_id': datetime.datetime(2017, 3, 19, 0, 0), 'total_numer_of_fire': 21}
# {'_id': datetime.datetime(2017, 3, 28, 0, 0), 'total_numer_of_fire': 54}
# {'_id': datetime.datetime(2017, 2, 4, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 5, 4, 0, 0), 'total_numer_of_fire': 49}
# {'_id': datetime.datetime(2017, 8, 4, 0, 0), 'total_numer_of_fire': 20}
# {'_id': datetime.datetime(2017, 3, 24, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 11, 4, 0, 0), 'total_numer_of_fire': 24}
# {'_id': datetime.datetime(2017, 12, 4, 0, 0), 'total_numer_of_fire': 69}
# {'_id': datetime.datetime(2017, 4, 13, 0, 0), 'total_numer_of_fire': 357}
# {'_id': datetime.datetime(2017, 4, 14, 0, 0), 'total_numer_of_fire': 18}
# {'_id': datetime.datetime(2017, 4, 15, 0, 0), 'total_numer_of_fire': 69}
# {'_id': datetime.datetime(2017, 4, 17, 0, 0), 'total_numer_of_fire': 38}
# {'_id': datetime.datetime(2017, 4, 19, 0, 0), 'total_numer_of_fire': 50}
# {'_id': datetime.datetime(2017, 4, 20, 0, 0), 'total_numer_of_fire': 31}
# {'_id': datetime.datetime(2017, 4, 18, 0, 0), 'total_numer_of_fire': 325}
# {'_id': datetime.datetime(2017, 4, 22, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 4, 23, 0, 0), 'total_numer_of_fire': 19}
# {'_id': datetime.datetime(2017, 4, 25, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 4, 26, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 4, 29, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 2, 5, 0, 0), 'total_numer_of_fire': 10}
# {'_id': datetime.datetime(2017, 4, 5, 0, 0), 'total_numer_of_fire': 135}
# {'_id': datetime.datetime(2017, 6, 5, 0, 0), 'total_numer_of_fire': 17}
# {'_id': datetime.datetime(2017, 12, 3, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 7, 5, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 9, 29, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 10, 9, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 7, 31, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 5, 13, 0, 0), 'total_numer_of_fire': 54}
# {'_id': datetime.datetime(2017, 4, 10, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 8, 10, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 5, 5, 0, 0), 'total_numer_of_fire': 31}
# {'_id': datetime.datetime(2017, 10, 10, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 3, 29, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 4, 24, 0, 0), 'total_numer_of_fire': 8}
# {'_id': datetime.datetime(2017, 6, 7, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 9, 5, 0, 0), 'total_numer_of_fire': 13}
# {'_id': datetime.datetime(2017, 10, 23, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 11, 6, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 10, 18, 0, 0), 'total_numer_of_fire': 6}
# {'_id': datetime.datetime(2017, 10, 21, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 12, 12, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 10, 28, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 8, 11, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 12, 13, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 5, 8, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 9, 12, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 5, 16, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 6, 30, 0, 0), 'total_numer_of_fire': 6}
# {'_id': datetime.datetime(2017, 12, 21, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 12, 25, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 1, 8, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 6, 22, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 12, 16, 0, 0), 'total_numer_of_fire': 15}
# {'_id': datetime.datetime(2017, 9, 11, 0, 0), 'total_numer_of_fire': 10}
# {'_id': datetime.datetime(2017, 1, 5, 0, 0), 'total_numer_of_fire': 20}
# {'_id': datetime.datetime(2017, 11, 29, 0, 0), 'total_numer_of_fire': 8}
# {'_id': datetime.datetime(2017, 2, 8, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 9, 10, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 8, 14, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 9, 27, 0, 0), 'total_numer_of_fire': 7}
# {'_id': datetime.datetime(2017, 10, 12, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 12, 27, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 3, 31, 0, 0), 'total_numer_of_fire': 22}
# {'_id': datetime.datetime(2017, 2, 10, 0, 0), 'total_numer_of_fire': 7}
# {'_id': datetime.datetime(2017, 3, 4, 0, 0), 'total_numer_of_fire': 72}
# {'_id': datetime.datetime(2017, 8, 12, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 5, 11, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 11, 30, 0, 0), 'total_numer_of_fire': 31}
# {'_id': datetime.datetime(2017, 7, 29, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 12, 14, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 10, 20, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 4, 16, 0, 0), 'total_numer_of_fire': 18}
# {'_id': datetime.datetime(2017, 11, 23, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 3, 6, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 11, 14, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 12, 15, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 9, 23, 0, 0), 'total_numer_of_fire': 23}
# {'_id': datetime.datetime(2017, 10, 8, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 3, 5, 0, 0), 'total_numer_of_fire': 64}
# {'_id': datetime.datetime(2017, 5, 7, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 11, 28, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 5, 18, 0, 0), 'total_numer_of_fire': 7}
# {'_id': datetime.datetime(2017, 10, 16, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 4, 4, 0, 0), 'total_numer_of_fire': 89}
# {'_id': datetime.datetime(2017, 6, 13, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 4, 6, 0, 0), 'total_numer_of_fire': 9}
# {'_id': datetime.datetime(2017, 3, 18, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 12, 24, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 11, 21, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 3, 10, 0, 0), 'total_numer_of_fire': 18}
# {'_id': datetime.datetime(2017, 10, 27, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 11, 22, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 1, 6, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 1, 10, 0, 0), 'total_numer_of_fire': 8}
# {'_id': datetime.datetime(2017, 11, 13, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 10, 26, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 2, 7, 0, 0), 'total_numer_of_fire': 8}
# {'_id': datetime.datetime(2017, 10, 15, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 11, 11, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 6, 4, 0, 0), 'total_numer_of_fire': 118}
# {'_id': datetime.datetime(2017, 9, 21, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 9, 26, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 9, 22, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 5, 22, 0, 0), 'total_numer_of_fire': 33}
# {'_id': datetime.datetime(2017, 10, 17, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 9, 20, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 7, 3, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 8, 13, 0, 0), 'total_numer_of_fire': 9}
# {'_id': datetime.datetime(2017, 4, 7, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 1, 7, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 6, 20, 0, 0), 'total_numer_of_fire': 6}
# {'_id': datetime.datetime(2017, 10, 3, 0, 0), 'total_numer_of_fire': 8}
# {'_id': datetime.datetime(2017, 6, 16, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 7, 14, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 6, 18, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 10, 5, 0, 0), 'total_numer_of_fire': 114}
# {'_id': datetime.datetime(2017, 6, 14, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 9, 6, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 9, 24, 0, 0), 'total_numer_of_fire': 28}
# {'_id': datetime.datetime(2017, 7, 6, 0, 0), 'total_numer_of_fire': 14}
# {'_id': datetime.datetime(2017, 12, 11, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 5, 15, 0, 0), 'total_numer_of_fire': 102}
# {'_id': datetime.datetime(2017, 2, 6, 0, 0), 'total_numer_of_fire': 11}
# {'_id': datetime.datetime(2017, 6, 10, 0, 0), 'total_numer_of_fire': 2}
# {'_id': datetime.datetime(2017, 5, 26, 0, 0), 'total_numer_of_fire': 4}
# {'_id': datetime.datetime(2017, 3, 26, 0, 0), 'total_numer_of_fire': 17}
# {'_id': datetime.datetime(2017, 5, 14, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 3, 14, 0, 0), 'total_numer_of_fire': 10}
# {'_id': datetime.datetime(2017, 7, 4, 0, 0), 'total_numer_of_fire': 39}
# {'_id': datetime.datetime(2017, 5, 23, 0, 0), 'total_numer_of_fire': 5}
# {'_id': datetime.datetime(2017, 12, 5, 0, 0), 'total_numer_of_fire': 10}
# {'_id': datetime.datetime(2017, 5, 24, 0, 0), 'total_numer_of_fire': 3}
# {'_id': datetime.datetime(2017, 5, 17, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 3, 25, 0, 0), 'total_numer_of_fire': 13}
# {'_id': datetime.datetime(2017, 1, 4, 0, 0), 'total_numer_of_fire': 7}
# {'_id': datetime.datetime(2017, 11, 5, 0, 0), 'total_numer_of_fire': 19}
# {'_id': datetime.datetime(2017, 7, 10, 0, 0), 'total_numer_of_fire': 1}
# {'_id': datetime.datetime(2017, 8, 5, 0, 0), 'total_numer_of_fire': 24}

# %%
# Q_g
result = collection_hotspot.aggregate([
        {
             "$group": {
                 "_id":"$date", "average_surface_temperature":{"$avg":"$surface_temperature_celcius"}
             }  
        }
        ])
for item in result:
    pprint(item)
# Out:
# {'_id': datetime.datetime(2017, 6, 3, 0, 0),
#  'average_surface_temperature': 60.5}
# {'_id': datetime.datetime(2017, 8, 3, 0, 0),
#  'average_surface_temperature': 51.5}
# {'_id': datetime.datetime(2017, 9, 3, 0, 0),
#  'average_surface_temperature': 46.666666666666664}
# {'_id': datetime.datetime(2017, 3, 13, 0, 0),
#  'average_surface_temperature': 38.5}
# {'_id': datetime.datetime(2017, 3, 15, 0, 0),
#  'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 3, 17, 0, 0),
#  'average_surface_temperature': 59.5}
# {'_id': datetime.datetime(2017, 3, 19, 0, 0),
#  'average_surface_temperature': 65.57142857142857}
# {'_id': datetime.datetime(2017, 3, 28, 0, 0),
#  'average_surface_temperature': 60.925925925925924}
# {'_id': datetime.datetime(2017, 2, 4, 0, 0),
#  'average_surface_temperature': 45.2}
# {'_id': datetime.datetime(2017, 5, 4, 0, 0),
#  'average_surface_temperature': 53.142857142857146}
# {'_id': datetime.datetime(2017, 8, 4, 0, 0),
#  'average_surface_temperature': 60.75}
# {'_id': datetime.datetime(2017, 3, 24, 0, 0),
#  'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 11, 4, 0, 0),
#  'average_surface_temperature': 46.291666666666664}
# {'_id': datetime.datetime(2017, 12, 4, 0, 0),
#  'average_surface_temperature': 52.69565217391305}
# {'_id': datetime.datetime(2017, 4, 13, 0, 0),
#  'average_surface_temperature': 58.57983193277311}
# {'_id': datetime.datetime(2017, 4, 14, 0, 0),
#  'average_surface_temperature': 61.94444444444444}
# {'_id': datetime.datetime(2017, 4, 15, 0, 0),
#  'average_surface_temperature': 59.57971014492754}
# {'_id': datetime.datetime(2017, 4, 17, 0, 0),
#  'average_surface_temperature': 50.921052631578945}
# {'_id': datetime.datetime(2017, 4, 19, 0, 0),
#  'average_surface_temperature': 54.16}
# {'_id': datetime.datetime(2017, 4, 20, 0, 0),
#  'average_surface_temperature': 56.58064516129032}
# {'_id': datetime.datetime(2017, 4, 18, 0, 0),
#  'average_surface_temperature': 53.36615384615384}
# {'_id': datetime.datetime(2017, 4, 22, 0, 0),
#  'average_surface_temperature': 54.5}
# {'_id': datetime.datetime(2017, 4, 23, 0, 0),
#  'average_surface_temperature': 53.89473684210526}
# {'_id': datetime.datetime(2017, 4, 25, 0, 0),
#  'average_surface_temperature': 48.666666666666664}
# {'_id': datetime.datetime(2017, 4, 26, 0, 0),
#  'average_surface_temperature': 34.0}
# {'_id': datetime.datetime(2017, 4, 29, 0, 0),
#  'average_surface_temperature': 63.0}
# {'_id': datetime.datetime(2017, 2, 5, 0, 0),
#  'average_surface_temperature': 55.6}
# {'_id': datetime.datetime(2017, 4, 5, 0, 0),
#  'average_surface_temperature': 56.80740740740741}
# {'_id': datetime.datetime(2017, 6, 5, 0, 0),
#  'average_surface_temperature': 57.529411764705884}
# {'_id': datetime.datetime(2017, 12, 3, 0, 0),
#  'average_surface_temperature': 88.2}
# {'_id': datetime.datetime(2017, 7, 5, 0, 0),
#  'average_surface_temperature': 50.333333333333336}
# {'_id': datetime.datetime(2017, 9, 29, 0, 0),
#  'average_surface_temperature': 43.0}
# {'_id': datetime.datetime(2017, 10, 9, 0, 0),
#  'average_surface_temperature': 56.5}
# {'_id': datetime.datetime(2017, 7, 31, 0, 0),
#  'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 5, 13, 0, 0),
#  'average_surface_temperature': 58.611111111111114}
# {'_id': datetime.datetime(2017, 4, 10, 0, 0),
#  'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 8, 10, 0, 0),
#  'average_surface_temperature': 41.0}
# {'_id': datetime.datetime(2017, 5, 5, 0, 0),
#  'average_surface_temperature': 51.70967741935484}
# {'_id': datetime.datetime(2017, 10, 10, 0, 0),
#  'average_surface_temperature': 53.333333333333336}
# {'_id': datetime.datetime(2017, 3, 29, 0, 0),
#  'average_surface_temperature': 51.0}
# {'_id': datetime.datetime(2017, 4, 24, 0, 0),
#  'average_surface_temperature': 59.375}
# {'_id': datetime.datetime(2017, 6, 7, 0, 0),
#  'average_surface_temperature': 56.0}
# {'_id': datetime.datetime(2017, 9, 5, 0, 0),
#  'average_surface_temperature': 42.46153846153846}
# {'_id': datetime.datetime(2017, 10, 23, 0, 0),
#  'average_surface_temperature': 38.0}
# {'_id': datetime.datetime(2017, 11, 6, 0, 0),
#  'average_surface_temperature': 41.5}
# {'_id': datetime.datetime(2017, 10, 18, 0, 0),
#  'average_surface_temperature': 52.166666666666664}
# {'_id': datetime.datetime(2017, 10, 21, 0, 0),
#  'average_surface_temperature': 51.25}
# {'_id': datetime.datetime(2017, 12, 12, 0, 0),
#  'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 10, 28, 0, 0),
#  'average_surface_temperature': 56.0}
# {'_id': datetime.datetime(2017, 8, 11, 0, 0),
#  'average_surface_temperature': 45.5}
# {'_id': datetime.datetime(2017, 12, 13, 0, 0),
#  'average_surface_temperature': 60.0}
# {'_id': datetime.datetime(2017, 5, 8, 0, 0),
#  'average_surface_temperature': 40.0}
# {'_id': datetime.datetime(2017, 9, 12, 0, 0),
#  'average_surface_temperature': 58.25}
# {'_id': datetime.datetime(2017, 5, 16, 0, 0),
#  'average_surface_temperature': 39.666666666666664}
# {'_id': datetime.datetime(2017, 6, 30, 0, 0),
#  'average_surface_temperature': 44.333333333333336}
# {'_id': datetime.datetime(2017, 12, 21, 0, 0),
#  'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 12, 25, 0, 0),
#  'average_surface_temperature': 54.0}
# {'_id': datetime.datetime(2017, 1, 8, 0, 0),
#  'average_surface_temperature': 58.0}
# {'_id': datetime.datetime(2017, 6, 22, 0, 0),
#  'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 12, 16, 0, 0),
#  'average_surface_temperature': 57.8}
# {'_id': datetime.datetime(2017, 9, 11, 0, 0),
#  'average_surface_temperature': 61.3}
# {'_id': datetime.datetime(2017, 1, 5, 0, 0),
#  'average_surface_temperature': 68.4}
# {'_id': datetime.datetime(2017, 11, 29, 0, 0),
#  'average_surface_temperature': 60.625}
# {'_id': datetime.datetime(2017, 2, 8, 0, 0),
#  'average_surface_temperature': 63.5}
# {'_id': datetime.datetime(2017, 9, 10, 0, 0),
#  'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 8, 14, 0, 0),
#  'average_surface_temperature': 40.8}
# {'_id': datetime.datetime(2017, 9, 27, 0, 0),
#  'average_surface_temperature': 49.714285714285715}
# {'_id': datetime.datetime(2017, 10, 12, 0, 0),
#  'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 12, 27, 0, 0),
#  'average_surface_temperature': 62.75}
# {'_id': datetime.datetime(2017, 3, 31, 0, 0),
#  'average_surface_temperature': 48.72727272727273}
# {'_id': datetime.datetime(2017, 2, 10, 0, 0),
#  'average_surface_temperature': 43.57142857142857}
# {'_id': datetime.datetime(2017, 3, 4, 0, 0),
#  'average_surface_temperature': 58.44444444444444}
# {'_id': datetime.datetime(2017, 8, 12, 0, 0),
#  'average_surface_temperature': 50.6}
# {'_id': datetime.datetime(2017, 5, 11, 0, 0),
#  'average_surface_temperature': 58.5}
# {'_id': datetime.datetime(2017, 11, 30, 0, 0),
#  'average_surface_temperature': 52.41935483870968}
# {'_id': datetime.datetime(2017, 7, 29, 0, 0),
#  'average_surface_temperature': 48.0}
# {'_id': datetime.datetime(2017, 12, 14, 0, 0),
#  'average_surface_temperature': 70.0}
# {'_id': datetime.datetime(2017, 10, 20, 0, 0),
#  'average_surface_temperature': 50.0}
# {'_id': datetime.datetime(2017, 4, 16, 0, 0),
#  'average_surface_temperature': 48.72222222222222}
# {'_id': datetime.datetime(2017, 11, 23, 0, 0),
#  'average_surface_temperature': 58.8}
# {'_id': datetime.datetime(2017, 3, 6, 0, 0),
#  'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 11, 14, 0, 0),
#  'average_surface_temperature': 52.0}
# {'_id': datetime.datetime(2017, 12, 15, 0, 0),
#  'average_surface_temperature': 39.0}
# {'_id': datetime.datetime(2017, 9, 23, 0, 0),
#  'average_surface_temperature': 52.73913043478261}
# {'_id': datetime.datetime(2017, 10, 8, 0, 0),
#  'average_surface_temperature': 63.0}
# {'_id': datetime.datetime(2017, 3, 5, 0, 0),
#  'average_surface_temperature': 56.796875}
# {'_id': datetime.datetime(2017, 5, 7, 0, 0),
#  'average_surface_temperature': 45.0}
# {'_id': datetime.datetime(2017, 11, 28, 0, 0),
#  'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 5, 18, 0, 0),
#  'average_surface_temperature': 44.142857142857146}
# {'_id': datetime.datetime(2017, 10, 16, 0, 0),
#  'average_surface_temperature': 36.0}
# {'_id': datetime.datetime(2017, 4, 4, 0, 0),
#  'average_surface_temperature': 62.57303370786517}
# {'_id': datetime.datetime(2017, 6, 13, 0, 0),
#  'average_surface_temperature': 41.0}
# {'_id': datetime.datetime(2017, 4, 6, 0, 0),
#  'average_surface_temperature': 52.22222222222222}
# {'_id': datetime.datetime(2017, 3, 18, 0, 0),
#  'average_surface_temperature': 79.33333333333333}
# {'_id': datetime.datetime(2017, 12, 24, 0, 0),
#  'average_surface_temperature': 32.0}
# {'_id': datetime.datetime(2017, 11, 21, 0, 0),
#  'average_surface_temperature': 59.0}
# {'_id': datetime.datetime(2017, 3, 10, 0, 0),
#  'average_surface_temperature': 50.0}
# {'_id': datetime.datetime(2017, 10, 27, 0, 0),
#  'average_surface_temperature': 50.4}
# {'_id': datetime.datetime(2017, 11, 22, 0, 0),
#  'average_surface_temperature': 61.5}
# {'_id': datetime.datetime(2017, 1, 6, 0, 0),
#  'average_surface_temperature': 54.0}
# {'_id': datetime.datetime(2017, 1, 10, 0, 0),
#  'average_surface_temperature': 48.25}
# {'_id': datetime.datetime(2017, 11, 13, 0, 0),
#  'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 10, 26, 0, 0),
#  'average_surface_temperature': 44.6}
# {'_id': datetime.datetime(2017, 2, 7, 0, 0),
#  'average_surface_temperature': 43.5}
# {'_id': datetime.datetime(2017, 10, 15, 0, 0),
#  'average_surface_temperature': 72.66666666666667}
# {'_id': datetime.datetime(2017, 11, 11, 0, 0),
#  'average_surface_temperature': 46.25}
# {'_id': datetime.datetime(2017, 6, 4, 0, 0),
#  'average_surface_temperature': 61.71186440677966}
# {'_id': datetime.datetime(2017, 9, 21, 0, 0),
#  'average_surface_temperature': 40.5}
# {'_id': datetime.datetime(2017, 9, 26, 0, 0),
#  'average_surface_temperature': 33.0}
# {'_id': datetime.datetime(2017, 9, 22, 0, 0),
#  'average_surface_temperature': 45.0}
# {'_id': datetime.datetime(2017, 5, 22, 0, 0),
#  'average_surface_temperature': 54.484848484848484}
# {'_id': datetime.datetime(2017, 10, 17, 0, 0),
#  'average_surface_temperature': 51.6}
# {'_id': datetime.datetime(2017, 9, 20, 0, 0),
#  'average_surface_temperature': 63.6}
# {'_id': datetime.datetime(2017, 7, 3, 0, 0),
#  'average_surface_temperature': 64.0}
# {'_id': datetime.datetime(2017, 8, 13, 0, 0),
#  'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 4, 7, 0, 0),
#  'average_surface_temperature': 40.0}
# {'_id': datetime.datetime(2017, 1, 7, 0, 0),
#  'average_surface_temperature': 30.5}
# {'_id': datetime.datetime(2017, 6, 20, 0, 0),
#  'average_surface_temperature': 71.16666666666667}
# {'_id': datetime.datetime(2017, 10, 3, 0, 0),
#  'average_surface_temperature': 69.375}
# {'_id': datetime.datetime(2017, 6, 16, 0, 0),
#  'average_surface_temperature': 42.5}
# {'_id': datetime.datetime(2017, 7, 14, 0, 0),
#  'average_surface_temperature': 41.5}
# {'_id': datetime.datetime(2017, 6, 18, 0, 0),
#  'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 10, 5, 0, 0),
#  'average_surface_temperature': 52.86842105263158}
# {'_id': datetime.datetime(2017, 6, 14, 0, 0),
#  'average_surface_temperature': 53.25}
# {'_id': datetime.datetime(2017, 9, 6, 0, 0),
#  'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 9, 24, 0, 0),
#  'average_surface_temperature': 53.57142857142857}
# {'_id': datetime.datetime(2017, 7, 6, 0, 0),
#  'average_surface_temperature': 51.857142857142854}
# {'_id': datetime.datetime(2017, 12, 11, 0, 0),
#  'average_surface_temperature': 53.0}
# {'_id': datetime.datetime(2017, 5, 15, 0, 0),
#  'average_surface_temperature': 53.950980392156865}
# {'_id': datetime.datetime(2017, 2, 6, 0, 0),
#  'average_surface_temperature': 47.72727272727273}
# {'_id': datetime.datetime(2017, 6, 10, 0, 0),
#  'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 5, 26, 0, 0),
#  'average_surface_temperature': 49.5}
# {'_id': datetime.datetime(2017, 3, 26, 0, 0),
#  'average_surface_temperature': 56.88235294117647}
# {'_id': datetime.datetime(2017, 5, 14, 0, 0),
#  'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 3, 14, 0, 0),
#  'average_surface_temperature': 65.6}
# {'_id': datetime.datetime(2017, 7, 4, 0, 0),
#  'average_surface_temperature': 50.69230769230769}
# {'_id': datetime.datetime(2017, 5, 23, 0, 0),
#  'average_surface_temperature': 51.2}
# {'_id': datetime.datetime(2017, 12, 5, 0, 0),
#  'average_surface_temperature': 51.5}
# {'_id': datetime.datetime(2017, 5, 24, 0, 0),
#  'average_surface_temperature': 40.333333333333336}
# {'_id': datetime.datetime(2017, 5, 17, 0, 0),
#  'average_surface_temperature': 52.0}
# {'_id': datetime.datetime(2017, 3, 25, 0, 0),
#  'average_surface_temperature': 66.0}
# {'_id': datetime.datetime(2017, 1, 4, 0, 0),
#  'average_surface_temperature': 46.714285714285715}
# {'_id': datetime.datetime(2017, 11, 5, 0, 0),
#  'average_surface_temperature': 59.36842105263158}
# {'_id': datetime.datetime(2017, 7, 10, 0, 0),
#  'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 8, 5, 0, 0),
#  'average_surface_temperature': 56.291666666666664}
